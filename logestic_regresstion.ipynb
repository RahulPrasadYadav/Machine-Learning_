# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=100, n_features=2, n_informative=1,n_redundant=0,
                           n_classes=2, n_clusters_per_class=1, random_state=41,hypercube=False,class_sep=10)

# %%
plt.Figure(figsize=(10, 8))
plt.scatter(X[:,0], X[:,1], c=y, s=50, cmap='viridis')

# %%
def step(z):
    return 1 if z>0 else 0

# %%
def precptron(x,y):
    x=np.insert(x,0,1,axis=1)
    wights=np.ones(x.shape[1])
    lr=0.01
    for i in range(1000):
        j=np.random.randint(0,1000)
        y_hat=step(np.dot(x[j],wights))
        wights=wights+lr*(y[j]-y_hat)*x[j]
    return wights[0],wights[1:]

# %%
interncept_,coef=precptron(X,y)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 interncept_,coef=precptron(X,y)
#
# Cell In[11], line 7, in precptron(x, y)
#       5 for i in range(1000):
#       6     j=np.random.randint(0,1000)
# ----> 7     y_hat=step(np.dot(x[j],wights))
#       8     wights=wights+lr*(y[j]-y_hat)*x[j]
#       9 return wights[0],wights[1:]
#
# IndexError: index 148 is out of bounds for axis 0 with size 100
